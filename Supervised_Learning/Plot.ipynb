# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
#read data
train_data = pd.read_csv('training_data.csv',header=None)
y = pd.read_csv('training_data_class_labels.csv',header=None)
train_data.columns=['X1','X2']
train_data['target'] = y
train_data
# Out:
#             X1        X2  target
# 0     0.389109 -0.271211       1
# 1     0.398587  0.258951       1
# 2    -0.809148  1.269477       0
# 3    -0.498385  1.292512       0
# 4    -0.022119  0.610184       0
# ...        ...       ...     ...
# 4245 -0.908800  1.375915       0
# 4246  0.073239  1.000319       0
# 4247 -0.810451  0.369553       1
# 4248  0.631457  0.337128       1
# 4249 -2.031238  0.565712       0
#
# [4250 rows x 3 columns]

# %%
class_0 = train_data.loc[train_data['target'] == 0]
class_1 = train_data.loc[train_data['target'] == 1]

# %%
plt.plot(class_0['X1'],class_0['X2'], '.')
plt.plot(class_1['X1'],class_1['X2'], '.')
